# %% [markdown]
# ## Regressão linear

# %%
import numpy as np
import pandas as pd
import sklearn.feature_selection as fs
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score
from sklearn.feature_selection import VarianceThreshold
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_regression
from sklearn.feature_selection import mutual_info_regression
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
def daterange(start_date, end_date):
    for i in range(int((end_date - start_date).days)):
         yield start_date + datetime.timedelta(i)

# %% [markdown]
# ## Exemplo com Adamantina

# %%
dataframe = pd.read_csv('../normalizados/dados/3500105.csv')
dataframe
# Out:
#      Unnamed: 0   Município  Código IBGE  Populacao  Total 1ª Dose  \
# 0             0  ADAMANTINA    3500105.0    35111.0       0.000000
# 1             1  ADAMANTINA    3500105.0    35111.0       0.000559
# 2             2  ADAMANTINA    3500105.0    35111.0       0.001829
# 3             3  ADAMANTINA    3500105.0    35111.0       0.002134
# 4             4  ADAMANTINA    3500105.0    35111.0       0.002896
# ..          ...         ...          ...        ...            ...
# 144         144  ADAMANTINA    3500105.0    35111.0       0.976066
# 145         145  ADAMANTINA    3500105.0    35111.0       0.990447
# 146         146  ADAMANTINA    3500105.0    35111.0       1.000000
# 147         147  ADAMANTINA    3500105.0    35111.0       1.000000
# 148         148  ADAMANTINA    3500105.0    35111.0       1.000000
#
#      Total 2ª Dose  Total Unica  Total Doses Aplicadas  \
# 0         0.067900          0.0               0.000000
# 1         0.068401          0.0               0.000540
# 2         0.076029          0.0               0.003638
# 3         0.076904          0.0               0.004106
# 4         0.092410          0.0               0.009112
# ..             ...          ...                    ...
# 144       0.988621          1.0               0.979759
# 145       0.996374          1.0               0.992184
# 146       1.000000          1.0               1.000000
# 147       1.000000          1.0               1.000000
# 148       1.000000          1.0               1.000000
#
#      População Vacinada dose1/População Total  \
# 0                                    0.000000
# 1                                    0.000559
# 2                                    0.001829
# 3                                    0.002134
# 4                                    0.002896
# ..                                        ...
# 144                                  0.976066
# 145                                  0.990447
# 146                                  1.000000
# 147                                  1.000000
# 148                                  1.000000
#
#      População Vacinada/População Total        data  diagnostico_covid19  \
# 0                              0.062927  2021-02-21              0.25000
# 1                              0.063391  2021-02-22              0.65625
# 2                              0.070460  2021-02-23              0.31250
# 3                              0.071271  2021-02-24              0.21875
# 4                              0.085641  2021-02-25              0.12500
# ..                                  ...         ...                  ...
# 144                            0.989454  2021-07-15              0.18750
# 145                            0.996639  2021-07-16              0.09375
# 146                            1.000000  2021-07-17              0.00000
# 147                            1.000000  2021-07-18              0.06250
# 148                            1.000000  2021-07-19              0.09375
#
#      obito  media_movel_casos  media_movel_obitos  ocupacao_leitos  \
# 0      0.5           0.568966            0.444444         0.437308
# 1      0.5           0.620690            0.444444         0.452059
# 2      0.0           0.482759            0.444444         0.466810
# 3      0.5           0.431034            0.444444         0.437308
# 4      0.5           0.275862            0.555556         0.351875
# ..     ...                ...                 ...              ...
# 144    0.0           0.198276            0.111111         0.110633
# 145    0.0           0.163793            0.111111         0.226490
# 146    0.0           0.060345            0.000000         0.092502
# 147    0.0           0.034483            0.000000         0.000000
# 148    0.0           0.008621            0.000000         0.066687
#
#      media_isolamento  Mean.R
# 0            0.462963     0.0
# 1            0.037037     0.0
# 2            0.111111     0.0
# 3            1.000000     0.0
# 4            0.092593     0.0
# ..                ...     ...
# 144          0.185185     0.0
# 145          0.074074     0.0
# 146          0.259259     0.0
# 147          0.611111     0.0
# 148          0.203704     0.0
#
# [149 rows x 18 columns]

# %% [markdown]
# ### *Seleção de atributos*

# %%
sel = fs.VarianceThreshold()
X = dataframe.drop(columns = ['Município', 'Código IBGE', 'data', 'diagnostico_covid19' ])
y = dataframe['diagnostico_covid19']

for i in range(9, 0, -1):
    sel = fs.SelectKBest(fs.mutual_info_regression, k=i)
    X_sel = sel.fit_transform(X, y)
    model = LinearRegression()
    scores_kfold = cross_val_score(estimator=model, X=X_sel, y=y, cv=9)
    score = scores_kfold.mean()
    print("Score com k = {} -> {}" .format(i, score))
# Out:
# Score com k = 9 -> 0.027652736561587572
# Score com k = 8 -> 0.03210439701024695
# Score com k = 7 -> 0.08262106609115534
# Score com k = 6 -> 0.08284892860707721
# Score com k = 5 -> 0.0918378103868368
# Score com k = 4 -> 0.11304821255355467
# Score com k = 3 -> 0.11304821255355502
# Score com k = 2 -> 0.09608268226175673
# Score com k = 1 -> 0.1110225835265747

# %%
#leitura
y_data = []
x_data = []

x_data = np.array(dataframe[['media_movel_casos', 'media_movel_obitos', 'ocupacao_leitos','media_isolamento', 'obito']])
y_data = np.array(dataframe['diagnostico_covid19'])

# %%
y_pred = []
y_true = []

X_train, X_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.7, random_state=42)
model = LinearRegression()
model.fit(X_train, y_train)

for i in range(0, len(y_data)):
    y_pred.append(model.predict([x_data[i]]).reshape(1, -1)[0])
    
y_pred = np.array(y_pred)
y_true = np.array(y_true)

# %%
plt.figure(figsize=(20, 6))
plt.plot(y_data, label='Valores Reais')
plt.plot(y_pred, label='Regressão Linear')
#plt.plot(dataframe['media_movel_casos'], label='Regressão Linear')
plt.legend()
plt.show()

# %%
reg = LinearRegression()
scores = cross_val_score(reg, x_data, y_data, cv=7)
print(scores)
print(scores.mean()*100)
# Out:
# [0.37962055 0.23935338 0.03494069 0.02751099 0.28440839 0.30172219
#  0.21016225]
# 21.110263386903657

# %% [markdown]
# ### Colando dados dos últimos

# %%
def generate_time_lags(df, n_lags):
    df_n = df.copy()
    for n in range(1, n_lags + 1):
        df_n[f"lag{n}"] = df_n["media_movel_casos"].shift(n)
    df_n = df_n.iloc[n_lags:]
    return df_n
    
input_dim = 5

#dataframe = pd.read_csv('../normalizados/dados/3500204.csv')
df_generated = generate_time_lags(dataframe, input_dim)
df_generated
# Out:
#      Unnamed: 0   Município  Código IBGE  Populacao  Total 1ª Dose  \
# 5             5  ADAMANTINA    3500105.0    35111.0       0.002896
# 6             6  ADAMANTINA    3500105.0    35111.0       0.002896
# 7             7  ADAMANTINA    3500105.0    35111.0       0.002896
# 8             8  ADAMANTINA    3500105.0    35111.0       0.007114
# 9             9  ADAMANTINA    3500105.0    35111.0       0.023324
# ..          ...         ...          ...        ...            ...
# 144         144  ADAMANTINA    3500105.0    35111.0       0.976066
# 145         145  ADAMANTINA    3500105.0    35111.0       0.990447
# 146         146  ADAMANTINA    3500105.0    35111.0       1.000000
# 147         147  ADAMANTINA    3500105.0    35111.0       1.000000
# 148         148  ADAMANTINA    3500105.0    35111.0       1.000000
#
#      Total 2ª Dose  Total Unica  Total Doses Aplicadas  \
# 5         0.092535          0.0               0.009148
# 6         0.092535          0.0               0.009148
# 7         0.092535          0.0               0.009148
# 8         0.094410          0.0               0.012678
# 9         0.125422          0.0               0.033099
# ..             ...          ...                    ...
# 144       0.988621          1.0               0.979759
# 145       0.996374          1.0               0.992184
# 146       1.000000          1.0               1.000000
# 147       1.000000          1.0               1.000000
# 148       1.000000          1.0               1.000000
#
#      População Vacinada dose1/População Total  \
# 5                                    0.002896
# 6                                    0.002896
# 7                                    0.002896
# 8                                    0.007114
# 9                                    0.023324
# ..                                        ...
# 144                                  0.976066
# 145                                  0.990447
# 146                                  1.000000
# 147                                  1.000000
# 148                                  1.000000
#
#      População Vacinada/População Total  ... media_movel_casos  \
# 5                              0.085757  ...          0.241379
# 6                              0.085757  ...          0.241379
# 7                              0.085757  ...          0.172414
# 8                              0.087496  ...          0.086207
# 9                              0.116236  ...          0.051724
# ..                                  ...  ...               ...
# 144                            0.989454  ...          0.198276
# 145                            0.996639  ...          0.163793
# 146                            1.000000  ...          0.060345
# 147                            1.000000  ...          0.034483
# 148                            1.000000  ...          0.008621
#
#      media_movel_obitos  ocupacao_leitos  media_isolamento  Mean.R      lag1  \
# 5              0.444444         0.377996          0.000000     0.0  0.275862
# 6              0.444444         0.466810          0.222222     0.0  0.241379
# 7              0.333333         0.484327          0.777778     0.0  0.241379
# 8              0.222222         0.513829          0.074074     0.0  0.172414
# 9              0.444444         0.602028          0.222222     0.0  0.086207
# ..                  ...              ...               ...     ...       ...
# 144            0.111111         0.110633          0.185185     0.0  0.224138
# 145            0.111111         0.226490          0.074074     0.0  0.198276
# 146            0.000000         0.092502          0.259259     0.0  0.163793
# 147            0.000000         0.000000          0.611111     0.0  0.060345
# 148            0.000000         0.066687          0.203704     0.0  0.034483
#
#          lag2      lag3      lag4      lag5
# 5    0.431034  0.482759  0.620690  0.568966
# 6    0.275862  0.431034  0.482759  0.620690
# 7    0.241379  0.275862  0.431034  0.482759
# 8    0.241379  0.241379  0.275862  0.431034
# 9    0.172414  0.241379  0.241379  0.275862
# ..        ...       ...       ...       ...
# 144  0.293103  0.250000  0.293103  0.327586
# 145  0.224138  0.293103  0.250000  0.293103
# 146  0.198276  0.224138  0.293103  0.250000
# 147  0.163793  0.198276  0.224138  0.293103
# 148  0.060345  0.163793  0.198276  0.224138
#
# [144 rows x 23 columns]

# %%
#leitura
y_data = []
x_data = []

x_data = df_generated.drop(columns = ['Unnamed: 0', 'Município', 'Código IBGE', 'diagnostico_covid19', 'data', 'População Vacinada/População Total', 'População Vacinada dose1/População Total', 'Total Doses Aplicadas', 'Total Unica'])
y_data = df_generated['diagnostico_covid19']
    
x_data = np.array(x_data)
y_data = np.array(y_data)

# %%
y_pred = []
y_true = []

X_train, X_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.70, random_state=42)
model = LinearRegression()
model.fit(X_train, y_train)

for i in range(0, len(y_data)):
    y_pred.append(model.predict([x_data[i]]).reshape(1, -1)[0])
    
y_pred = np.array(y_pred)
y_true = np.array(y_true)

# %%
plt.figure(figsize=(20, 6))
plt.plot(y_data, 'o', label='Valores Reais')
plt.plot(y_pred, label='Regressão Linear')
plt.legend()
plt.show()

# %%
reg = LinearRegression()
scores = cross_val_score(reg, x_data, y_data, cv=5)
print(scores)
print(scores.mean()*100)
# Out:
# [ 0.49717008  0.6217231   0.58385809  0.18670964 -0.38237291]
# 30.141760274407904

# %% [markdown]
# ## Normalização utilizando standard

# %%
dataframe = pd.read_csv('../Finais/3500105.csv')
dataframe
# Out:
#      Unnamed: 0  Unnamed: 0.1   Município  Código IBGE  Populacao  \
# 0             0             0  ADAMANTINA    3500105.0    35111.0
# 1             1             1  ADAMANTINA    3500105.0    35111.0
# 2             2             2  ADAMANTINA    3500105.0    35111.0
# 3             3             3  ADAMANTINA    3500105.0    35111.0
# 4             4             4  ADAMANTINA    3500105.0    35111.0
# ..          ...           ...         ...          ...        ...
# 144         144           144  ADAMANTINA    3500105.0    35111.0
# 145         145           145  ADAMANTINA    3500105.0    35111.0
# 146         146           146  ADAMANTINA    3500105.0    35111.0
# 147         147           147  ADAMANTINA    3500105.0    35111.0
# 148         148           148  ADAMANTINA    3500105.0    35111.0
#
#      Total 1ª Dose  Total 2ª Dose  Total Unica  Total Doses Aplicadas  \
# 0           2068.0          543.0          0.0                 2611.0
# 1           2079.0          547.0          0.0                 2626.0
# 2           2104.0          608.0          0.0                 2712.0
# 3           2110.0          615.0          0.0                 2725.0
# 4           2125.0          739.0          0.0                 2864.0
# ..             ...            ...          ...                    ...
# 144        21276.0         7906.0        632.0                29814.0
# 145        21559.0         7968.0        632.0                30159.0
# 146        21747.0         7997.0        632.0                30376.0
# 147        21747.0         7997.0        632.0                30376.0
# 148        21747.0         7997.0        632.0                30376.0
#
#      População Vacinada dose1/População Total  \
# 0                                    5.889892
# 1                                    5.921221
# 2                                    5.992424
# 3                                    6.009513
# 4                                    6.052234
# ..                                        ...
# 144                                 60.596394
# 145                                 61.402410
# 146                                 61.937854
# 147                                 61.937854
# 148                                 61.937854
#
#      População Vacinada/População Total        data  diagnostico_covid19  \
# 0                              1.546524  2021-02-21                 11.0
# 1                              1.557916  2021-02-22                 24.0
# 2                              1.731651  2021-02-23                 13.0
# 3                              1.751588  2021-02-24                 10.0
# 4                              2.104753  2021-02-25                  7.0
# ..                                  ...         ...                  ...
# 144                           24.317166  2021-07-15                  9.0
# 145                           24.493748  2021-07-16                  6.0
# 146                           24.576344  2021-07-17                  3.0
# 147                           24.576344  2021-07-18                  5.0
# 148                           24.576344  2021-07-19                  6.0
#
#      obito  media_movel_casos  media_movel_obitos  ocupacao_leitos  \
# 0      1.0          16.571429            0.571429            79.81
# 1      1.0          17.428571            0.571429            80.29
# 2      0.0          15.142857            0.571429            80.77
# 3      1.0          14.285714            0.571429            79.81
# 4      1.0          11.714286            0.714286            77.03
# ..     ...                ...                 ...              ...
# 144    0.0          10.428571            0.142857            69.18
# 145    0.0           9.857143            0.142857            72.95
# 146    0.0           8.142857            0.000000            68.59
# 147    0.0           7.714286            0.000000            65.58
# 148    0.0           7.285714            0.000000            67.75
#
#      media_isolamento  Mean.R
# 0               43.00     0.0
# 1               37.25     0.0
# 2               38.25     0.0
# 3               50.25     0.0
# 4               38.00     0.0
# ..                ...     ...
# 144             39.25     0.0
# 145             37.75     0.0
# 146             40.25     0.0
# 147             45.00     0.0
# 148             39.50     0.0
#
# [149 rows x 19 columns]

# %%
scaler = StandardScaler()
norma = scaler.fit_transform(dataframe.drop(columns = ['Unnamed: 0', 'Município', 'Código IBGE', 'data']))
df_scaled = pd.DataFrame(norma, columns=dataframe.drop(columns = ['Unnamed: 0', 'Município', 'Código IBGE', 'data']).columns)
#
# [149 rows x 18 columns]

# %%
#leitura
y_data = []
x_data = []

#quantidade de dias para o deslocamento
dias = 0

for x in range(dias, dataframe.shape[0]):
    aux = dataframe.loc[x][['media_movel_casos', 'media_movel_obitos', 'ocupacao_leitos','media_isolamento', 'Mean.R', 'obito']]
    x_data.append(aux.values.tolist())
    y_data.append(dataframe.loc[x]['diagnostico_covid19'].tolist())
    
x_data = np.array(x_data)
y_data = np.array(y_data)

# %%
y_pred = []
y_true = []

X_train, X_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.70, random_state=42)
model = LinearRegression()
model.fit(X_train, y_train)

for i in range(0, len(y_data)):
    y_pred.append(model.predict([x_data[i]]).reshape(1, -1)[0])
    
y_pred = np.array(y_pred)
y_true = np.array(y_true)

# %%
plt.figure(figsize=(20, 6))
plt.plot(y_data, 'o', label='Valores Reais')
plt.plot(y_pred, label='Regressão Linear')
plt.legend()
plt.show()

# %%
reg = LinearRegression()
scores = cross_val_score(reg, x_data, y_data, cv=5)
print(scores)
print(scores.mean()*100)
# Out:
# [0.41090038 0.35003882 0.31458461 0.07554777 0.33501474]
# 29.721726238988854

# %%
df_generated = generate_time_lags(df_scaled, input_dim)
df_generated
# Out:
#      Unnamed: 0.1  Populacao  Total 1ª Dose  Total 2ª Dose  Total Unica  \
# 5       -1.604217        0.0      -1.378283      -1.595321    -0.250856
# 6       -1.580968        0.0      -1.378283      -1.595321    -0.250856
# 7       -1.557718        0.0      -1.378283      -1.595321    -0.250856
# 8       -1.534469        0.0      -1.363561      -1.589043    -0.250856
# 9       -1.511219        0.0      -1.306976      -1.485258    -0.250856
# ..            ...        ...            ...            ...          ...
# 144      1.627467        0.0       2.018727       1.403590     4.468007
# 145      1.650716        0.0       2.068926       1.429536     4.468007
# 146      1.673966        0.0       2.102273       1.441673     4.468007
# 147      1.697216        0.0       2.102273       1.441673     4.468007
# 148      1.720465        0.0       2.102273       1.441673     4.468007
#
#      Total Doses Aplicadas  População Vacinada dose1/População Total  \
# 5                -1.465933                                 -1.378283
# 6                -1.465933                                 -1.378283
# 7                -1.465933                                 -1.378283
# 8                -1.453566                                 -1.363561
# 9                -1.382010                                 -1.306976
# ..                     ...                                       ...
# 144               1.935050                                  2.018727
# 145               1.978589                                  2.068926
# 146               2.005975                                  2.102273
# 147               2.005975                                  2.102273
# 148               2.005975                                  2.102273
#
#      População Vacinada/População Total  diagnostico_covid19     obito  ...  \
# 5                             -1.577243            -1.483435 -0.806242  ...
# 6                             -1.577243            -1.014153 -0.806242  ...
# 7                             -1.577243            -1.796290 -0.806242  ...
# 8                             -1.571091            -0.075589 -0.806242  ...
# 9                             -1.469378            -0.857726  1.987481  ...
# ..                                  ...                  ...       ...  ...
# 144                            1.620987            -0.857726 -0.806242  ...
# 145                            1.646415            -1.327008 -0.806242  ...
# 146                            1.658309            -1.796290 -0.806242  ...
# 147                            1.658309            -1.483435 -0.806242  ...
# 148                            1.658309            -1.327008 -0.806242  ...
#
#      media_isolamento  Mean.R   Município  Código IBGE        data      lag1  \
# 5           -1.234891     0.0  ADAMANTINA    3500105.0  2021-02-26 -0.665283
# 6           -0.257906     0.0  ADAMANTINA    3500105.0  2021-02-27 -0.793852
# 7            2.184555     0.0  ADAMANTINA    3500105.0  2021-02-28 -0.793852
# 8           -0.909230     0.0  ADAMANTINA    3500105.0  2021-03-01 -1.050992
# 9           -0.257906     0.0  ADAMANTINA    3500105.0  2021-03-02 -1.372416
# ..                ...     ...         ...          ...         ...       ...
# 144         -0.420737     0.0  ADAMANTINA    3500105.0  2021-07-15 -0.858137
# 145         -0.909230     0.0  ADAMANTINA    3500105.0  2021-07-16 -0.954564
# 146         -0.095076     0.0  ADAMANTINA    3500105.0  2021-07-17 -1.083134
# 147          1.451817     0.0  ADAMANTINA    3500105.0  2021-07-18 -1.468843
# 148         -0.339322     0.0  ADAMANTINA    3500105.0  2021-07-19 -1.565270
#
#          lag2      lag3      lag4      lag5
# 5   -0.086720  0.106135  0.620413  0.427559
# 6   -0.665283 -0.086720  0.106135  0.620413
# 7   -0.793852 -0.665283 -0.086720  0.106135
# 8   -0.793852 -0.793852 -0.665283 -0.086720
# 9   -1.050992 -0.793852 -0.793852 -0.665283
# ..        ...       ...       ...       ...
# 144 -0.600998 -0.761710 -0.600998 -0.472429
# 145 -0.858137 -0.600998 -0.761710 -0.600998
# 146 -0.954564 -0.858137 -0.600998 -0.761710
# 147 -1.083134 -0.954564 -0.858137 -0.600998
# 148 -1.468843 -1.083134 -0.954564 -0.858137
#
# [144 rows x 23 columns]

# %%
#leitura
y_data = []
x_data = []

x_data = df_generated.drop(columns = ['Município', 'Mean.R','Código IBGE', 'diagnostico_covid19', 'data', 'População Vacinada/População Total', 'População Vacinada dose1/População Total', 'Total Doses Aplicadas', 'Total Unica'])
y_data = df_generated['diagnostico_covid19']
    
x_data = np.array(x_data)
y_data = np.array(y_data)

# %%
y_pred = []
y_true = []

X_train, X_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.70, random_state=42)
model = LinearRegression()
model.fit(X_train, y_train)

for i in range(0, len(y_data)):
    y_pred.append(model.predict([x_data[i]]).reshape(1, -1)[0])
    
y_pred = np.array(y_pred)
y_true = np.array(y_true)

# %%
plt.figure(figsize=(20, 6))
plt.plot(y_data, 'o', label='Valores Reais')
plt.plot(y_pred, label='Regressão Linear')
plt.legend()
plt.show()

# %%
reg = LinearRegression()
scores = cross_val_score(reg, x_data, y_data, cv=5)
print(scores)
print(scores.mean()*100)
# Out:
# [ 0.54608269  0.6366094   0.52631791  0.35113627 -0.01223621]
# 40.95820114665775

# %% [markdown]
# ### *Verificando modelo para óbitos*

# %%
def generate_time_lags_obitos(df, n_lags):
    df_n = df.copy()
    for n in range(1, n_lags + 1):
        df_n[f"lag{n}"] = df_n["media_movel_obitos"].shift(n)
    df_n = df_n.iloc[n_lags:]
    return df_n

# %%
dataframe = pd.read_csv('../normalizados/dados/3500105.csv')
dataframe = generate_time_lags_obitos(dataframe, input_dim)
dataframe
# Out:
#      Unnamed: 0   Município  Código IBGE  Populacao  Total 1ª Dose  \
# 5             5  ADAMANTINA    3500105.0    35111.0       0.002896
# 6             6  ADAMANTINA    3500105.0    35111.0       0.002896
# 7             7  ADAMANTINA    3500105.0    35111.0       0.002896
# 8             8  ADAMANTINA    3500105.0    35111.0       0.007114
# 9             9  ADAMANTINA    3500105.0    35111.0       0.023324
# ..          ...         ...          ...        ...            ...
# 144         144  ADAMANTINA    3500105.0    35111.0       0.976066
# 145         145  ADAMANTINA    3500105.0    35111.0       0.990447
# 146         146  ADAMANTINA    3500105.0    35111.0       1.000000
# 147         147  ADAMANTINA    3500105.0    35111.0       1.000000
# 148         148  ADAMANTINA    3500105.0    35111.0       1.000000
#
#      Total 2ª Dose  Total Unica  Total Doses Aplicadas  \
# 5         0.092535          0.0               0.009148
# 6         0.092535          0.0               0.009148
# 7         0.092535          0.0               0.009148
# 8         0.094410          0.0               0.012678
# 9         0.125422          0.0               0.033099
# ..             ...          ...                    ...
# 144       0.988621          1.0               0.979759
# 145       0.996374          1.0               0.992184
# 146       1.000000          1.0               1.000000
# 147       1.000000          1.0               1.000000
# 148       1.000000          1.0               1.000000
#
#      População Vacinada dose1/População Total  \
# 5                                    0.002896
# 6                                    0.002896
# 7                                    0.002896
# 8                                    0.007114
# 9                                    0.023324
# ..                                        ...
# 144                                  0.976066
# 145                                  0.990447
# 146                                  1.000000
# 147                                  1.000000
# 148                                  1.000000
#
#      População Vacinada/População Total  ... media_movel_casos  \
# 5                              0.085757  ...          0.241379
# 6                              0.085757  ...          0.241379
# 7                              0.085757  ...          0.172414
# 8                              0.087496  ...          0.086207
# 9                              0.116236  ...          0.051724
# ..                                  ...  ...               ...
# 144                            0.989454  ...          0.198276
# 145                            0.996639  ...          0.163793
# 146                            1.000000  ...          0.060345
# 147                            1.000000  ...          0.034483
# 148                            1.000000  ...          0.008621
#
#      media_movel_obitos  ocupacao_leitos  media_isolamento  Mean.R      lag1  \
# 5              0.444444         0.377996          0.000000     0.0  0.555556
# 6              0.444444         0.466810          0.222222     0.0  0.444444
# 7              0.333333         0.484327          0.777778     0.0  0.444444
# 8              0.222222         0.513829          0.074074     0.0  0.333333
# 9              0.444444         0.602028          0.222222     0.0  0.222222
# ..                  ...              ...               ...     ...       ...
# 144            0.111111         0.110633          0.185185     0.0  0.111111
# 145            0.111111         0.226490          0.074074     0.0  0.111111
# 146            0.000000         0.092502          0.259259     0.0  0.111111
# 147            0.000000         0.000000          0.611111     0.0  0.000000
# 148            0.000000         0.066687          0.203704     0.0  0.000000
#
#          lag2      lag3      lag4      lag5
# 5    0.444444  0.444444  0.444444  0.444444
# 6    0.555556  0.444444  0.444444  0.444444
# 7    0.444444  0.555556  0.444444  0.444444
# 8    0.444444  0.444444  0.555556  0.444444
# 9    0.333333  0.444444  0.444444  0.555556
# ..        ...       ...       ...       ...
# 144  0.111111  0.222222  0.222222  0.222222
# 145  0.111111  0.111111  0.222222  0.222222
# 146  0.111111  0.111111  0.111111  0.222222
# 147  0.111111  0.111111  0.111111  0.111111
# 148  0.000000  0.111111  0.111111  0.111111
#
# [144 rows x 23 columns]

# %%
sel = fs.VarianceThreshold()
X = dataframe.drop(columns = ['Município', 'Código IBGE', 'data', 'obito', 'Unnamed: 0'])
y = dataframe['obito']

maior = 0
param = []
for i in range(9, 0, -1):
    sel = fs.SelectKBest(fs.mutual_info_regression, k=i)
    X_sel = sel.fit_transform(X, y)
    model = LinearRegression()
    scores_kfold = cross_val_score(estimator=model, X=X_sel, y=y, cv=9)
    score = scores_kfold.mean()
    if(score > maior):
        maior = score
        param = X_sel
        
    print("Score com k = {} -> {}" .format(i, score))
# Out:
# Score com k = 9 -> -2.85766300527785e+24
# Score com k = 8 -> -5.968498711195153e+24
# Score com k = 7 -> -4.6211282288630114e+24
# Score com k = 6 -> 0.06232865789410966
# Score com k = 5 -> 0.10648021297471012
# Score com k = 4 -> -0.03020471671716956
# Score com k = 3 -> 0.015537989037607367
# Score com k = 2 -> 0.07883981134388934
# Score com k = 1 -> -0.3550759031115292

# %%
print(param)
# Out:
# [[0.00289649 0.00914821 0.00289649 0.44444444 0.55555556]
#  [0.00289649 0.00914821 0.00289649 0.44444444 0.44444444]
#  [0.00289649 0.00914821 0.00289649 0.33333333 0.44444444]
#  [0.00711418 0.01267783 0.00711418 0.22222222 0.33333333]
#  [0.02332436 0.03309923 0.02332436 0.44444444 0.22222222]
#  [0.04248183 0.05056726 0.04248183 0.33333333 0.44444444]
#  [0.04253265 0.05060328 0.04253265 0.22222222 0.33333333]
#  [0.04593729 0.05773456 0.04593729 0.22222222 0.22222222]
#  [0.06143605 0.07156492 0.06143605 0.33333333 0.22222222]
#  [0.06143605 0.07156492 0.06143605 0.44444444 0.33333333]
#  [0.06285889 0.07286152 0.06285889 0.55555556 0.44444444]
#  [0.06743229 0.07621106 0.06743229 0.33333333 0.55555556]
#  [0.06880431 0.08049703 0.06880431 0.33333333 0.33333333]
#  [0.06997307 0.08334234 0.06997307 0.33333333 0.33333333]
#  [0.0717008  0.08553935 0.0717008  0.55555556 0.33333333]
#  [0.09106154 0.09926166 0.09106154 0.44444444 0.55555556]
#  [0.09106154 0.09926166 0.09106154 0.33333333 0.44444444]
#  [0.09278927 0.10149469 0.09278927 0.22222222 0.33333333]
#  [0.09431374 0.10275527 0.09431374 0.22222222 0.22222222]
#  [0.09492352 0.10343958 0.09492352 0.22222222 0.22222222]
#  [0.09538086 0.10401585 0.09538086 0.22222222 0.22222222]
#  [0.09685451 0.10516838 0.09685451 0.         0.22222222]
#  [0.13344174 0.13110031 0.13344174 0.22222222 0.        ]
#  [0.13344174 0.07502251 0.13344174 0.22222222 0.22222222]
#  [0.13577926 0.07667927 0.13577926 0.33333333 0.22222222]
#  [0.13684638 0.13401765 0.13684638 0.44444444 0.33333333]
#  [0.13771025 0.14060868 0.13771025 0.66666667 0.44444444]
#  [0.13771025 0.1406447  0.13771025 0.66666667 0.66666667]
#  [0.13903145 0.14179723 0.13903145 0.66666667 0.66666667]
#  [0.13903145 0.14179723 0.13903145 0.55555556 0.66666667]
#  [0.17866762 0.17061048 0.17866762 0.55555556 0.55555556]
#  [0.18197063 0.17709346 0.18197063 0.55555556 0.55555556]
#  [0.18344428 0.18559337 0.18344428 0.55555556 0.55555556]
#  [0.18354591 0.18732217 0.18354591 0.44444444 0.55555556]
#  [0.18430815 0.1889069  0.18430815 0.55555556 0.44444444]
#  [0.18430815 0.1889069  0.18430815 0.66666667 0.55555556]
#  [0.20133137 0.20165676 0.20133137 0.55555556 0.66666667]
#  [0.20133137 0.20165676 0.20133137 0.77777778 0.55555556]
#  [0.20270339 0.20338556 0.20270339 0.77777778 0.77777778]
#  [0.20377052 0.2045741  0.20377052 0.88888889 0.77777778]
#  [0.20427867 0.20518639 0.20427867 0.77777778 0.88888889]
#  [0.94781239 0.91590131 0.94781239 0.22222222 0.11111111]
#  [0.94781239 0.91590131 0.94781239 0.22222222 0.22222222]
#  [0.94781239 0.91806231 0.94781239 0.22222222 0.22222222]
#  [0.94862544 0.94024851 0.94862544 0.11111111 0.22222222]
#  [0.95934753 0.96668467 0.95934753 0.11111111 0.11111111]
#  [0.97606586 0.97975869 0.97606586 0.11111111 0.11111111]
#  [0.99044667 0.9921844  0.99044667 0.11111111 0.11111111]
#  [1.         1.         1.         0.         0.11111111]
#  [1.         1.         1.         0.         0.        ]
#  [1.         1.         1.         0.         0.        ]]

# %%
y_data = []
x_data = []

x_data = dataframe[['media_movel_obitos', 'Total Doses Aplicadas']]
y_data = dataframe['obito']
    
x_data = np.array(x_data)
y_data = np.array(y_data)

# %%
y_pred = []
y_true = []

X_train, X_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.50, random_state=42)
model = LinearRegression()
model.fit(X_train, y_train)

for i in range(0, len(y_data)):
    y_pred.append(model.predict([x_data[i]]).reshape(1, -1)[0])
    
y_pred = np.array(y_pred)
y_true = np.array(y_true)

# %%
plt.figure(figsize=(20, 6))
plt.plot(y_data, 'o', label='Valores Reais')
plt.plot(y_pred, label='Regressão Linear')
plt.legend()
plt.show()

# %%
reg = LinearRegression()
scores = cross_val_score(reg, x_data, y_data, cv=5)
print(scores)
print(scores.mean()*100)
# Out:
# [0.1111017  0.22134255 0.1594847  0.07831458 0.27604937]
# 16.925857998278776

# %%
y_data = []
x_data = []

x_data = dataframe[['media_movel_obitos', 'Total Doses Aplicadas', 'lag1', 'lag2', 'lag3']]
y_data = dataframe['obito']
    
x_data = np.array(x_data)
y_data = np.array(y_data)

y_pred = []
y_true = []

X_train, X_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.50, random_state=42)
model = LinearRegression()
model.fit(X_train, y_train)

for i in range(0, len(y_data)):
    y_pred.append(model.predict([x_data[i]]).reshape(1, -1)[0])
    
y_pred = np.array(y_pred)
y_true = np.array(y_true)

plt.figure(figsize=(20, 6))
plt.plot(y_data, 'o', label='Valores Reais')
plt.plot(y_pred, label='Regressão Linear')
plt.legend()
plt.show()

reg = LinearRegression()
scores = cross_val_score(reg, x_data, y_data, cv=5)
print(scores)
print(scores.mean()*100)
# Out:
# [0.67515201 0.50743236 0.65156763 0.39970872 0.51782234]
# 55.033661090677185

# %% [markdown]
# ### *Verificando modelo para média móvel de óbitos*

# %%
sel = fs.VarianceThreshold()
X = dataframe.drop(columns = ['Município', 'Código IBGE', 'data', 'media_movel_obitos', 'Unnamed: 0'])
y = dataframe['media_movel_obitos']

maior = 0
param = []
for i in range(9, 0, -1):
    sel = fs.SelectKBest(fs.mutual_info_regression, k=i)
    X_sel = sel.fit_transform(X, y)
    model = LinearRegression()
    scores_kfold = cross_val_score(estimator=model, X=X_sel, y=y, cv=9)
    score = scores_kfold.mean()
    if(score > maior):
        maior = score
        param = X_sel
        
    print("Score com k = {} -> {}" .format(i, score))
# Out:
# Score com k = 9 -> -3.511235731233933e+24
# Score com k = 8 -> -3.8491592668438396e+25
# Score com k = 7 -> -1.125607684226736e+25
# Score com k = 6 -> -5.944071914558311e+24
# Score com k = 5 -> -3.6659758232782336e+24
# Score com k = 4 -> -11.743494588209984
# Score com k = 3 -> -11.688500771584517
# Score com k = 2 -> -11.688868288843768
# Score com k = 1 -> -8.546214342626783
