# %%
import pandas as pd

# %%
sjc = pd.read_csv('../Finais/3549904.csv').drop(columns=['Unnamed: 0','Unnamed: 0.1'])
sjc
# Out:
#                Município  Código IBGE  Populacao  Total 1ª Dose  \
# 0    SÃO JOSÉ DOS CAMPOS    3549904.0   729737.0         3918.0
# 1    SÃO JOSÉ DOS CAMPOS    3549904.0   729737.0        10157.0
# 2    SÃO JOSÉ DOS CAMPOS    3549904.0   729737.0        16967.0
# 3    SÃO JOSÉ DOS CAMPOS    3549904.0   729737.0        23293.0
# 4    SÃO JOSÉ DOS CAMPOS    3549904.0   729737.0        26466.0
# ..                   ...          ...        ...            ...
# 144  SÃO JOSÉ DOS CAMPOS    3549904.0   729737.0       357185.0
# 145  SÃO JOSÉ DOS CAMPOS    3549904.0   729737.0       364904.0
# 146  SÃO JOSÉ DOS CAMPOS    3549904.0   729737.0       364941.0
# 147  SÃO JOSÉ DOS CAMPOS    3549904.0   729737.0       364941.0
# 148  SÃO JOSÉ DOS CAMPOS    3549904.0   729737.0       364941.0
#
#      Total 2ª Dose  Total Unica  Total Doses Aplicadas  \
# 0            206.0          0.0                 4124.0
# 1             84.0          0.0                10241.0
# ...
