# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.graph_objs as go
from plotly.offline import iplot

# %%
def plot_dataset(df, title):
    
    data = []
    value = go.Scatter(
        x=df.index,
        y=df.value,
        mode="lines",
        name="values",
        marker=dict(),
        text=df.index,
        line=dict(color="rgba(0,0,0, 0.3)"),
    )
    data.append(value)

    layout = dict(
        title=title,
        xaxis=dict(title="Date", ticklen=5, zeroline=False),
        yaxis=dict(title="Value", ticklen=5, zeroline=False),
    )

    fig = dict(data=data, layout=layout)
    iplot(fig)

# %% [markdown]
# # LSTM

# %%
dataframe = pd.read_csv('../normalizados/dados/3500105.csv')
dataframe
# Out:
#      Unnamed: 0   Município  Código IBGE  Populacao  Total 1ª Dose  \
# 0             0  ADAMANTINA    3500105.0    35111.0      -1.388394
# 1             1  ADAMANTINA    3500105.0    35111.0      -1.386443
# 2             2  ADAMANTINA    3500105.0    35111.0      -1.382008
# 3             3  ADAMANTINA    3500105.0    35111.0      -1.380944
# 4             4  ADAMANTINA    3500105.0    35111.0      -1.378283
# ..          ...         ...          ...        ...            ...
# 144         144  ADAMANTINA    3500105.0    35111.0       2.018727
# 145         145  ADAMANTINA    3500105.0    35111.0       2.068926
# 146         146  ADAMANTINA    3500105.0    35111.0       2.102273
# 147         147  ADAMANTINA    3500105.0    35111.0       2.102273
# 148         148  ADAMANTINA    3500105.0    35111.0       2.102273
#
#      Total 2ª Dose  Total Unica  Total Doses Aplicadas  \
# 0        -1.677764    -0.250856              -1.497988
# 1        -1.676090    -0.250856              -1.496095
# 2        -1.650562    -0.250856              -1.485242
# 3        -1.647632    -0.250856              -1.483601
# 4        -1.595739    -0.250856              -1.466059
# ..             ...          ...                    ...
# 144       1.403590     4.468007               1.935050
# 145       1.429536     4.468007               1.978589
# 146       1.441673     4.468007               2.005975
# 147       1.441673     4.468007               2.005975
# 148       1.441673     4.468007               2.005975
#
#      População Vacinada dose1/População Total  \
# 0                                   -1.388394
# 1                                   -1.386443
# 2                                   -1.382008
# 3                                   -1.380944
# 4                                   -1.378283
# ..                                        ...
# 144                                  2.018727
# 145                                  2.068926
# 146                                  2.102273
# 147                                  2.102273
# 148                                  2.102273
#
#      População Vacinada/População Total        data  diagnostico_covid19  \
# 0                             -1.658040  2021-02-21            -0.544871
# 1                             -1.656399  2021-02-22             1.488685
# 2                             -1.631381  2021-02-23            -0.232016
# 3                             -1.628510  2021-02-24            -0.701299
# 4                             -1.577653  2021-02-25            -1.170581
# ..                                  ...         ...                  ...
# 144                            1.620987  2021-07-15            -0.857726
# 145                            1.646415  2021-07-16            -1.327008
# 146                            1.658309  2021-07-17            -1.796290
# 147                            1.658309  2021-07-18            -1.483435
# 148                            1.658309  2021-07-19            -1.327008
#
#         obito  media_movel_casos  media_movel_obitos  ocupacao_leitos  \
# 0    0.590619           0.427559           -0.043846        -1.657499
# 1    0.590619           0.620413           -0.043846        -1.590281
# 2   -0.806242           0.106135           -0.043846        -1.523063
# 3    0.590619          -0.086720           -0.043846        -1.657499
# 4    0.590619          -0.665283            0.391689        -2.046804
# ..        ...                ...                 ...              ...
# 144 -0.806242          -0.954564           -1.350450        -3.146099
# 145 -0.806242          -1.083134           -1.350450        -2.618157
# 146 -0.806242          -1.468843           -1.785985        -3.228721
# 147 -0.806242          -1.565270           -1.785985        -3.650234
# 148 -0.806242          -1.661697           -1.785985        -3.346352
#
#      media_isolamento  Mean.R
# 0            0.800494     0.0
# 1           -1.072060     0.0
# 2           -0.746399     0.0
# 3            3.161540     0.0
# 4           -0.827814     0.0
# ..                ...     ...
# 144         -0.420737     0.0
# 145         -0.909230     0.0
# 146         -0.095076     0.0
# 147          1.451817     0.0
# 148         -0.339322     0.0
#
# [149 rows x 18 columns]

# %%
dataframe = dataframe.set_index(['data'])
dataframe.index = pd.to_datetime(dataframe.index)
dataframe = dataframe.rename(columns={'diagnostico_covid19': 'value'})
if not dataframe.index.is_monotonic:
    dataframe = dataframe.sort_index()
    
plot_dataset(dataframe, title='Casos')
# Out:
# <div>                            <div id="ae8410b7-86fd-4c18-940e-f7d5c16ca3fd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ae8410b7-86fd-4c18-940e-f7d5c16ca3fd")) {                    Plotly.newPlot(                        "ae8410b7-86fd-4c18-940e-f7d5c16ca3fd",                        [{"line": {"color": "rgba(0,0,0, 0.3)"}, "mode": "lines", "name": "values", "text": ["2021-02-21T00:00:00", "2021-02-22T00:00:00", "2021-02-23T00:00:00", "2021-02-24T00:00:00", "2021-02-25T00:00:00", "2021-02-26T00:00:00", "2021-02-27T00:00:00", "2021-02-28T00:00:00", "2021-03-01T00:00:00", "2021-03-02T00:00:00", "2021-03-03T00:00:00", "2021-03-04T00:00:00", "2021-03-05T00:00:00", "2021-03-06T00:00:00", "2021-03-07T00:00:00", "2021-03-08T00:00:00", "2021-03-09T00:00:00", "2021-03-10T00:00:00", "2021-03-11T00:00:00", "2021-03-12T00:00:00", "2021-03-13T00:00:00", "2021-03-14T00:00:00", "2021-03-15T00:00:00", "2021-03-16T00:00:00", "2021-03-17T00:00:00", "2021-03-18T00:00:00", "2021-03-19T00:00:00", "2021-03-20T00:00:00", "2021-03-21T00:00:00", "2021-03-22T00:00:00", "2021-03-23T00:00:00", "2021-03-24T00:00:00", "2021-03-25T00:00:00", "2021-03-26T00:00:00", "2021-03-27T00:00:00", "2021-03-28T00:00:00", "2021-03-29T00:00:00", "2021-03-30T00:00:00", "2021-03-31T00:00:00", "2021-04-01T00:00:00", "2021-04-02T00:00:00", "2021-04-03T00:00:00", "2021-04-04T00:00:00", "2021-04-05T00:00:00", "2021-04-06T00:00:00", "2021-04-07T00:00:00", "2021-04-08T00:00:00", "2021-04-09T00:00:00", "2021-04-10T00:00:00", "2021-04-11T00:00:00", "2021-04-12T00:00:00", "2021-04-13T00:00:00", "2021-04-14T00:00:00", "2021-04-15T00:00:00", "2021-04-16T00:00:00", "2021-04-17T00:00:00", "2021-04-18T00:00:00", "2021-04-19T00:00:00", "2021-04-20T00:00:00", "2021-04-21T00:00:00", "2021-04-22T00:00:00", "2021-04-23T00:00:00", "2021-04-24T00:00:00", "2021-04-25T00:00:00", "2021-04-26T00:00:00", "2021-04-27T00:00:00", "2021-04-28T00:00:00", "2021-04-29T00:00:00", "2021-04-30T00:00:00", "2021-05-01T00:00:00", "2021-05-02T00:00:00", "2021-05-03T00:00:00", "2021-05-04T00:00:00", "2021-05-05T00:00:00", "2021-05-06T00:00:00", "2021-05-07T00:00:00", "2021-05-08T00:00:00", "2021-05-09T00:00:00", "2021-05-10T00:00:00", "2021-05-11T00:00:00", "2021-05-12T00:00:00", "2021-05-13T00:00:00", "2021-05-14T00:00:00", "2021-05-15T00:00:00", "2021-05-16T00:00:00", "2021-05-17T00:00:00", "2021-05-18T00:00:00", "2021-05-19T00:00:00", "2021-05-20T00:00:00", "2021-05-21T00:00:00", "2021-05-22T00:00:00", "2021-05-23T00:00:00", "2021-05-24T00:00:00", "2021-05-25T00:00:00", "2021-05-26T00:00:00", "2021-05-27T00:00:00", "2021-05-28T00:00:00", "2021-05-29T00:00:00", "2021-05-30T00:00:00", "2021-05-31T00:00:00", "2021-06-01T00:00:00", "2021-06-02T00:00:00", "2021-06-03T00:00:00", "2021-06-04T00:00:00", "2021-06-05T00:00:00", "2021-06-06T00:00:00", "2021-06-07T00:00:00", "2021-06-08T00:00:00", "2021-06-09T00:00:00", "2021-06-10T00:00:00", "2021-06-11T00:00:00", "2021-06-12T00:00:00", "2021-06-13T00:00:00", "2021-06-14T00:00:00", "2021-06-15T00:00:00", "2021-06-16T00:00:00", "2021-06-17T00:00:00", "2021-06-18T00:00:00", "2021-06-19T00:00:00", "2021-06-20T00:00:00", "2021-06-21T00:00:00", "2021-06-22T00:00:00", "2021-06-23T00:00:00", "2021-06-24T00:00:00", "2021-06-25T00:00:00", "2021-06-26T00:00:00", "2021-06-27T00:00:00", "2021-06-28T00:00:00", "2021-06-29T00:00:00", "2021-06-30T00:00:00", "2021-07-01T00:00:00", "2021-07-02T00:00:00", "2021-07-03T00:00:00", "2021-07-04T00:00:00", "2021-07-05T00:00:00", "2021-07-06T00:00:00", "2021-07-07T00:00:00", "2021-07-08T00:00:00", "2021-07-09T00:00:00", "2021-07-10T00:00:00", "2021-07-11T00:00:00", "2021-07-12T00:00:00", "2021-07-13T00:00:00", "2021-07-14T00:00:00", "2021-07-15T00:00:00", "2021-07-16T00:00:00", "2021-07-17T00:00:00", "202 ...

# %%
def generate_time_lags(df, n_lags):
    df_n = df.copy()
    for n in range(1, n_lags + 1):
        df_n[f"lag{n}"] = df_n["value"].shift(n)
    df_n = df_n.iloc[n_lags:]
    return df_n
    
input_dim = 12

df_generated = generate_time_lags(dataframe, input_dim)
df_generated
# Out:
#             Unnamed: 0   Município  Código IBGE  Populacao  Total 1ª Dose  \
# data
# 2021-03-05          12  ADAMANTINA    3500105.0    35111.0      -1.228042
# 2021-03-06          13  ADAMANTINA    3500105.0    35111.0      -1.173941
# 2021-03-07          14  ADAMANTINA    3500105.0    35111.0      -1.173941
# 2021-03-08          15  ADAMANTINA    3500105.0    35111.0      -1.168974
# 2021-03-09          16  ADAMANTINA    3500105.0    35111.0      -1.153010
# ...                ...         ...          ...        ...            ...
# 2021-07-15         144  ADAMANTINA    3500105.0    35111.0       2.018727
# 2021-07-16         145  ADAMANTINA    3500105.0    35111.0       2.068926
# 2021-07-17         146  ADAMANTINA    3500105.0    35111.0       2.102273
# 2021-07-18         147  ADAMANTINA    3500105.0    35111.0       2.102273
# 2021-07-19         148  ADAMANTINA    3500105.0    35111.0       2.102273
#
#             Total 2ª Dose  Total Unica  Total Doses Aplicadas  \
# data
# 2021-03-05      -1.385238    -0.250856              -1.295688
# 2021-03-06      -1.352177    -0.250856              -1.247227
# 2021-03-07      -1.352177    -0.250856              -1.247227
# 2021-03-08      -1.348829    -0.250856              -1.242684
# 2021-03-09      -1.347574    -0.250856              -1.230947
# ...                   ...          ...                    ...
# 2021-07-15       1.403590     4.468007               1.935050
# 2021-07-16       1.429536     4.468007               1.978589
# 2021-07-17       1.441673     4.468007               2.005975
# 2021-07-18       1.441673     4.468007               2.005975
# 2021-07-19       1.441673     4.468007               2.005975
#
#             População Vacinada dose1/População Total  \
# data
# 2021-03-05                                 -1.228042
# 2021-03-06                                 -1.173941
# 2021-03-07                                 -1.173941
# 2021-03-08                                 -1.168974
# 2021-03-09                                 -1.153010
# ...                                              ...
# 2021-07-15                                  2.018727
# 2021-07-16                                  2.068926
# 2021-07-17                                  2.102273
# 2021-07-18                                  2.102273
# 2021-07-19                                  2.102273
#
#             População Vacinada/População Total  ...      lag3      lag4  \
# data                                            ...
# 2021-03-05                           -1.371355  ... -0.857726 -0.075589
# 2021-03-06                           -1.338955  ... -0.388444 -0.857726
# 2021-03-07                           -1.338955  ... -1.170581 -0.388444
# 2021-03-08                           -1.335674  ... -0.388444 -1.170581
# 2021-03-09                           -1.334443  ... -0.388444 -0.388444
# ...                                        ...  ...       ...       ...
# 2021-07-15                            1.620987  ... -0.857726 -1.014153
# 2021-07-16                            1.646415  ... -0.701299 -0.857726
# 2021-07-17                            1.658309  ... -0.388444 -0.701299
# 2021-07-18                            1.658309  ... -0.857726 -0.388444
# 2021-07-19                            1.658309  ... -1.327008 -0.857726
#
#                 lag5      lag6      lag7      lag8      lag9     lag10  \
# data
# 2021-03-05 -1.796290 -1.014153 -1.483435 -1.170581 -0.701299 -0.232016
# 2021-03-06 -0.075589 -1.796290 -1.014153 -1.483435 -1.170581 -0.701299
# 2021-03-07 -0.857726 -0.075589 -1.796290 -1.014153 -1.483435 -1.170581
# 2021-03-08 -0.388444 -0.857726 -0.075589 -1.796290 -1.014153 -1.483435
# 2021-03-09 -1.170581 -0.388444 -0.857726 -0.075589 -1.796290 -1.014153
# ...              ...       ...       ...       ...       ...       ...
# 2021-07-15  0.080838 -0.701299 -0.388444  0.862975 -1.483435 -0.075589
# 2021-07-16 -1.014153  0.080838 -0.701299 -0.388444  0.862975 -1.483435
# 2021-07-17 -0.857726 -1.014153  0.080838 -0.701299 -0.388444  0.862975
# 2021-07-18 -0.701299 -0.857726 -1.014153  0.080838 -0.701299 -0.388444
# 2021-07-19 -0.388444 -0.701299 -0.857726 -1.014153  0.080838 -0.701299
#
#                lag11     lag12
# data
# 2021-03-05  1.488685 -0.544871
# 2021-03-06 -0.232016  1.488685
# 2021-03-07 -0.701299 -0.232016
# 2021-03-08 -1.170581 -0.701299
# 2021-03-09 -1.483435 -1.170581
# ...              ...       ...
# 2021-07-15 -0.388444 -0.388444
# 2021-07-16 -0.075589 -0.388444
# 2021-07-17 -1.483435 -0.075589
# 2021-07-18  0.862975 -1.483435
# 2021-07-19 -0.388444  0.862975
#
# [137 rows x 29 columns]

# %%
df_features = (
                dataframe
                .assign(hour = dataframe.index.hour)
                .assign(day = dataframe.index.day)
                .assign(month = dataframe.index.month)
                .assign(day_of_week = dataframe.index.dayofweek)
                .assign(week_of_year = dataframe.index.isocalendar().week)
              )

# %%
def onehot_encode_pd(df, col_name):
    dummies = pd.get_dummies(df[col_name], prefix=col_name)
    return pd.concat([df, dummies], axis=1).drop(columns=[col_name])

df_features = onehot_encode_pd(df_features, ['month','day','day_of_week','week_of_year'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-88-b4f4ed9cb19c> in <module>
#       3     return pd.concat([df, dummies], axis=1).drop(columns=[col_name])
#       4
# ----> 5 df_features = onehot_encode_pd(df_features, ['month','day','day_of_week','week_of_year'])
#
# <ipython-input-88-b4f4ed9cb19c> in onehot_encode_pd(df, col_name)
#       1 def onehot_encode_pd(df, col_name):
# ----> 2     dummies = pd.get_dummies(df[col_name], prefix=col_name)
#       3     return pd.concat([df, dummies], axis=1).drop(columns=[col_name])
#       4
#       5 df_features = onehot_encode_pd(df_features, ['month','day','day_of_week','week_of_year'])
#
# c:\users\victor pedrota\appdata\local\programs\python\python39\lib\site-packages\pandas\core\reshape\reshape.py in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     859                     raise ValueError(len_msg)
#     860
# --> 861         check_len(prefix, "prefix")
#     862         check_len(prefix_sep, "prefix_sep")
#     863
#
# c:\users\victor pedrota\appdata\local\programs\python\python39\lib\site-packages\pandas\core\reshape\reshape.py in check_len(item, name)
#     857                         f"({data_to_encode.shape[1]})."
#     858                     )
# --> 859                     raise ValueError(len_msg)
#     860
#     861         check_len(prefix, "prefix")
#
# ValueError: Length of 'prefix' (4) did not match the length of the columns being encoded (0).

# %%
onehot_encoded
# Out:
# array([[0, 'ADAMANTINA', 3500105.0, ..., 2, 6, 7],
#        [1, 'ADAMANTINA', 3500105.0, ..., 2, 0, 8],
#        [2, 'ADAMANTINA', 3500105.0, ..., 2, 1, 8],
#        ...,
#        [146, 'ADAMANTINA', 3500105.0, ..., 7, 5, 28],
#        [147, 'ADAMANTINA', 3500105.0, ..., 7, 6, 28],
#        [148, 'ADAMANTINA', 3500105.0, ..., 7, 0, 29]], dtype=object)
